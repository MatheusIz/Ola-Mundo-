# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusIz/Ola-Mundo-/blob/MatheusIz/Linguagem_de_Programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##U1_A1

# %%
#1º Aula na linguagem de Programação
print("Hello, World!")
# Out:
# Hello, World!

# %%
#Criando uma Variavelde tipos diferentes
x = 10
Nome = 'Izaias'
Nota = 7.5
Fez_Inscrição = True

# %%
print(x)
print(Nome)
print(Nota)
print(Fez_Inscrição)
# Out:
# 10
# Izaias
# 7.5
# True

# %%
print(type(x))
print(type(Nome))
print(type(Nota))
print(type(Fez_Inscrição))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
Nome = input("Digite seu nome: ")
print("Olá,", Nome, "Matheus izaias  ")
# Out:
# Digite seu nome: Matheus
# Olá, Matheus  Matheus izaias

# %%
print(f"Olá (Nome), bem vindo à disciplina de programação")
# Out:
# Olá (Nome), bem vindo à disciplina de programação
